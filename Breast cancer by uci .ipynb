# %%
import pandas as pd

df=pd.read_csv('C:\\Users\\nEW u\\Desktop\\DataSEts\\breast-cancer-wisconsin.csv')
df.columns=['Id', 'Clump_thickness', 'Uniformity_cell_size', 'Uniformity_cell_shape', 'Marginal_adhesion', 
            'Single_e_cell_size', 'Bare_nuclei', 'Bland_chromatin', 'Normal_nucleoli', 'Mitoses', 'Class']
df.head()
# Out:
#         Id  Clump_thickness  Uniformity_cell_size  Uniformity_cell_shape  \
# 0  1002945                5                     4                      4
# 1  1015425                3                     1                      1
# 2  1016277                6                     8                      8
# 3  1017023                4                     1                      1
# 4  1017122                8                    10                     10
#
#    Marginal_adhesion  Single_e_cell_size Bare_nuclei  Bland_chromatin  \
# 0                  5                   7          10                3
# 1                  1                   2           2                3
# 2                  1                   3           4                3
# 3                  3                   2           1                3
# 4                  8                   7          10                9
#
#    Normal_nucleoli  Mitoses  Class
# 0                2        1      2
# ...

# %%
#df.isnull() is to check if there is any null value or not
# sum() will print the sum of all the null values
df.isnull().sum()
# Out:
# Id                       0
# Clump_thickness          0
# Uniformity_cell_size     0
# Uniformity_cell_shape    0
# Marginal_adhesion        0
# Single_e_cell_size       0
# Bare_nuclei              0
# Bland_chromatin          0
# Normal_nucleoli          0
# Mitoses                  0
# Class                    0
# dtype: int64

# %%
#droping the columns which are not required.
df.drop(['Id'], axis='columns',inplace=True)

# %%
#after droping the columns lets check the dataframe
df.head()
# Out:
#    Clump_thickness  Uniformity_cell_size  Uniformity_cell_shape  \
# 0                5                     4                      4
# 1                3                     1                      1
# 2                6                     8                      8
# 3                4                     1                      1
# 4                8                    10                     10
#
#    Marginal_adhesion  Single_e_cell_size Bare_nuclei  Bland_chromatin  \
# 0                  5                   7          10                3
# 1                  1                   2           2                3
# 2                  1                   3           4                3
# 3                  3                   2           1                3
# 4                  8                   7          10                9
#
#    Normal_nucleoli  Mitoses  Class
# 0                2        1      2
# 1                1        1      2
# 2                7        1      2
# ...

# %%
#unique element in the target features
df['Class'].unique()
# Out:
# array([2, 4], dtype=int64)

# %%
#importing the required library
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style('whitegrid')
sns.countplot(df.Class, palette="magma")

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(), annot=True,cmap="YlGnBu")

# %%
plt.figure(figsize=(10,5))
sns.countplot(df.Mitoses,hue=df['Class'], data=df ,orient='v', palette="magma")

# %%
df.columns
# Out:
# Index(['Clump_thickness', 'Uniformity_cell_size', 'Uniformity_cell_shape',
#        'Marginal_adhesion', 'Single_e_cell_size', 'Bare_nuclei',
#        'Bland_chromatin', 'Normal_nucleoli', 'Mitoses', 'Class'],
#       dtype='object')

# %%
for i in df.columns:
    plt.figure(figsize=(10,5))
    sns.countplot(df[i], hue=df['Class'], palette="cubehelix_r")
    plt.show()

# %%
sns.pairplot(df,hue='Class',palette="viridis")

# %%
df1=df[df.Class==2]
#surveys_df[surveys_df.year == 2002]
df1.head()
# Out:
#    Clump_thickness  Uniformity_cell_size  Uniformity_cell_shape  \
# 0                5                     4                      4
# 1                3                     1                      1
# 2                6                     8                      8
# 3                4                     1                      1
# 5                1                     1                      1
#
#    Marginal_adhesion  Single_e_cell_size Bare_nuclei  Bland_chromatin  \
# 0                  5                   7          10                3
# 1                  1                   2           2                3
# 2                  1                   3           4                3
# 3                  3                   2           1                3
# 5                  1                   2          10                3
#
#    Normal_nucleoli  Mitoses  Class
# 0                2        1      2
# 1                1        1      2
# 2                7        1      2
# ...

# %%
df1['Class'].unique()
# Out:
# array([2], dtype=int64)

# %%
df1.columns
# Out:
# Index(['Clump_thickness', 'Uniformity_cell_size', 'Uniformity_cell_shape',
#        'Marginal_adhesion', 'Single_e_cell_size', 'Bare_nuclei',
#        'Bland_chromatin', 'Normal_nucleoli', 'Mitoses', 'Class'],
#       dtype='object')

# %%
sns.pairplot(df1,hue='Class')

# %%
df.describe()
# Out:
#        Clump_thickness  Uniformity_cell_size  Uniformity_cell_shape  \
# count       698.000000            698.000000             698.000000
# mean          4.416905              3.137536               3.210602
# std           2.817673              3.052575               2.972867
# min           1.000000              1.000000               1.000000
# 25%           2.000000              1.000000               1.000000
# 50%           4.000000              1.000000               1.000000
# 75%           6.000000              5.000000               5.000000
# max          10.000000             10.000000              10.000000
#
#        Marginal_adhesion  Single_e_cell_size  Bare_nuclei  Bland_chromatin  \
# count         698.000000          698.000000   698.000000       698.000000
# mean            2.809456            3.217765     3.467049         3.438395
# std             2.856606            2.215408     3.642122         2.440056
# ...

# %%
df['Bare_nuclei'].unique()
# Out:
# array(['10', '2', '4', '1', '3', '9', '7', '?', '5', '8', '6'],
#       dtype=object)

# %%
# replaceing '?' with 0
df['Bare_nuclei'].replace({'?':'0'},inplace=True)
df['Bare_nuclei'].unique()
# Out:
# array(['10', '2', '4', '1', '3', '9', '7', '0', '5', '8', '6'],
#       dtype=object)

# %%
#covert object type to integer type datatype
df['Bare_nuclei']=df['Bare_nuclei'].astype(int)

# %%
#differentiate target features with the independent features
x=df.drop(['Class'],axis='columns')
y=df.Class

# %%
x.head()
# Out:
#    Clump_thickness  Uniformity_cell_size  Uniformity_cell_shape  \
# 0                5                     4                      4
# 1                3                     1                      1
# 2                6                     8                      8
# 3                4                     1                      1
# 4                8                    10                     10
#
#    Marginal_adhesion  Single_e_cell_size  Bare_nuclei  Bland_chromatin  \
# 0                  5                   7           10                3
# 1                  1                   2            2                3
# 2                  1                   3            4                3
# 3                  3                   2            1                3
# 4                  8                   7           10                9
#
#    Normal_nucleoli  Mitoses
# 0                2        1
# 1                1        1
# 2                7        1
# 3                1        1
# ...

# %%
y.head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    4
# Name: Class, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
# Out:
# C:\Users\Public\anacondainstallation\lib\site-packages\sklearn\preprocessing\data.py:617: DataConversionWarning: Data with input dtype int32, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Public\anacondainstallation\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype int32, int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 9 columns):
# Clump_thickness          698 non-null int64
# Uniformity_cell_size     698 non-null int64
# Uniformity_cell_shape    698 non-null int64
# Marginal_adhesion        698 non-null int64
# Single_e_cell_size       698 non-null int64
# Bare_nuclei              698 non-null int32
# Bland_chromatin          698 non-null int64
# Normal_nucleoli          698 non-null int64
# Mitoses                  698 non-null int64
# dtypes: int32(1), int64(8)
# memory usage: 46.4 KB

# %%
df['Bare_nuclei'].dtype
# Out:
# dtype('int32')

# %%
x_scaled_data=pd.DataFrame(data=x_scaled, columns=x.columns)

# %%
x_scaled_data.head()
# Out:
#    Clump_thickness  Uniformity_cell_size  Uniformity_cell_shape  \
# 0         0.207090              0.282739               0.265725
# 1        -0.503224             -0.700742              -0.744126
# 2         0.562247              1.594048               1.612192
# 3        -0.148067             -0.700742              -0.744126
# 4         1.272562              2.249702               2.285426
#
#    Marginal_adhesion  Single_e_cell_size  Bare_nuclei  Bland_chromatin  \
# 0           0.767385            1.708465     1.795007        -0.179795
# 1          -0.633883           -0.550074    -0.403089        -0.179795
# 2          -0.633883           -0.098366     0.146435        -0.179795
# 3           0.066751           -0.550074    -0.677851        -0.179795
# 4           1.818335            1.708465     1.795007         2.280928
#
#    Normal_nucleoli   Mitoses
# 0        -0.284861 -0.344187
# 1        -0.612427 -0.344187
# 2         1.352972 -0.344187
# 3        -0.612427 -0.344187
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_scaled_data,y,test_size=0.2)

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 558
# 140

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.metrics import confusion_matrix
y_pred=model.predict(X_test)
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[87,  3],
#        [ 7, 43]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_LR))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.93      0.97      0.95        90
#            4       0.93      0.86      0.90        50
#
#    micro avg       0.93      0.93      0.93       140
#    macro avg       0.93      0.91      0.92       140
# weighted avg       0.93      0.93      0.93       140

# %%
plt.figure(figsize=(10,5))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
# Out:
# Text(73.5,0.5,'True')

# %%
model.score(X_test,y_test)
# Out:
# 0.9285714285714286

# %%
from sklearn.ensemble import RandomForestClassifier
model_RF=RandomForestClassifier(n_estimators=100, min_samples_leaf=100, max_features=5)
model_RF.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features=5, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=100, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred_RF=model.predict(X_test)
cm_RF=confusion_matrix(y_test,y_pred_RF)
cm_RF
# Out:
# array([[87,  3],
#        [ 7, 43]], dtype=int64)

# %%
y_pred_LR=model.predict(X_test)
cm_LR=confusion_matrix(y_test,y_pred_LR)
cm_LR
# Out:
# array([[87,  3],
#        [ 7, 43]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_LR))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.93      0.97      0.95        90
#            4       0.93      0.86      0.90        50
#
#    micro avg       0.93      0.93      0.93       140
#    macro avg       0.93      0.91      0.92       140
# weighted avg       0.93      0.93      0.93       140

# %%
model_RF.score(X_test,y_test)
# Out:
# 0.95

# %%
plt.figure(figsize=(10,5))
sns.heatmap(cm_LR, annot=True, fmt='d', cmap="YlGnBu")
plt.xlabel('Predicted')
plt.ylabel('True')
# Out:
# Text(73.5,0.5,'True')

# %%
from sklearn.svm import SVC
model_SVC=SVC(kernel='rbf')
model_SVC.fit(X_train,y_train)
# Out:
# C:\Users\Public\anacondainstallation\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
y_pred_SVC=model.predict(X_test)
cm_SVC=confusion_matrix(y_test,y_pred_SVC)
cm_SVC
# Out:
# array([[87,  3],
#        [ 7, 43]], dtype=int64)
